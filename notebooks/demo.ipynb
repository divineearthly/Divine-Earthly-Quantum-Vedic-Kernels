# %% [markdown]
# # Hybrid AI + Symbolic Kernel Demo
# This notebook demonstrates the neuro-symbolic workflow: Dataset -> Neural Model -> Vedic Kernel Reasoning.

# %%
import torch
import pandas as pd
import sys
sys.path.append('..')
from ai_layer.dataset_loader import DatasetLoader
print('Environment Ready')
